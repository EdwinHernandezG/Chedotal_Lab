# %%
from skimage.io import imread
import napari_accelerated_pixel_and_object_classification  # version 0.12.3
import napari
viewer = napari.Viewer()

# %% [markdown]
# ## Loading 'C1-Reunion Edwin 160223.lif - M156 40x s3 Hopx Sox2'

# %%
image0_C = imread(
    "F:/CI2A/Image Analysis/Aixa/Pilar/split/C1-Reunion Edwin 160223.lif - M156 40x s3 Hopx Sox2.tif")
viewer.add_image(
    image0_C, name='C1-Reunion Edwin 160223.lif - M156 40x s3 Hopx Sox2')
napari.utils.nbscreenshot(viewer)
# Out:
# 2023-06-30 15:02:45.492 | ERROR    | napari_assistant._gui._category_widget:gui_function:431 - An error has been caught in function 'gui_function', process 'MainProcess' (37388), thread 'MainThread' (22712):
# Traceback (most recent call last):
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#            │         │     └ {'__name__': '__main__', '__doc__': 'Entry point for launching an IPython kernel.\n\nThis is separate from the ipykernel pack...
#            │         └ <code object <module> at 0x00000151C33849D0, file "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\ipykern...
#            └ <function _run_code at 0x00000151C3572C10>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#          │     └ {'__name__': '__main__', '__doc__': 'Entry point for launching an IPython kernel.\n\nThis is separate from the ipykernel pack...
#          └ <code object <module> at 0x00000151C33849D0, file "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\ipykern...
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#     │   └ <bound method Application.launch_instance of <class 'ipykernel.kernelapp.IPKernelApp'>>
#     └ <module 'ipykernel.kernelapp' from 'C:\\Users\\elful\\miniconda3\\envs\\devbio-napari-env\\lib\\site-packages\\ipykernel\\ker...
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#     │   └ <function IPKernelApp.start at 0x00000151C7A8A280>
#     └ <ipykernel.kernelapp.IPKernelApp object at 0x00000151C31DB0A0>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\ipykernel\kernelapp.py", line 725, in start
#     self.io_loop.start()
#     │    │       └ <function BaseAsyncIOLoop.start at 0x00000151C7A8ADC0>
#     │    └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x00000151C7ADC340>
#     └ <ipykernel.kernelapp.IPKernelApp object at 0x00000151C31DB0A0>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\tornado\platform\asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#     │    │            └ <function BaseEventLoop.run_forever at 0x00000151C533DA60>
#     │    └ <_WindowsSelectorEventLoop running=True closed=False debug=False>
#     └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x00000151C7ADC340>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\asyncio\base_events.py", line 601, in run_forever
#     self._run_once()
#     │    └ <function BaseEventLoop._run_once at 0x00000151C53405E0>
#     └ <_WindowsSelectorEventLoop running=True closed=False debug=False>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\asyncio\base_events.py", line 1905, in _run_once
#     handle._run()
#     │      └ <function Handle._run at 0x00000151C52CFAF0>
#     └ <TimerHandle when=778646.5009999275 IOLoop._run_callback(functools.par...0151C7AD4940>))>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#     │    │            │    │           │    └ <member '_args' of 'Handle' objects>
#     │    │            │    │           └ <TimerHandle when=778646.5009999275 IOLoop._run_callback(functools.par...0151C7AD4940>))>
#     │    │            │    └ <member '_callback' of 'Handle' objects>
#     │    │            └ <TimerHandle when=778646.5009999275 IOLoop._run_callback(functools.par...0151C7AD4940>))>
#     │    └ <member '_context' of 'Handle' objects>
#     └ <TimerHandle when=778646.5009999275 IOLoop._run_callback(functools.par...0151C7AD4940>))>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\tornado\ioloop.py", line 738, in _run_callback
#     ret = callback()
#           └ functools.partial(<function Kernel.enter_eventloop.<locals>.advance_eventloop at 0x00000151C7AD4940>)
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\ipykernel\kernelbase.py", line 458, in advance_eventloop
#     eventloop(self)
#     │         └ <ipykernel.ipkernel.IPythonKernel object at 0x00000151C7AD6E50>
#     └ <function loop_qt at 0x00000151C7A693A0>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\ipykernel\eventloops.py", line 128, in loop_qt
#     el.exec() if hasattr(el, 'exec') else el.exec_()
#     │  │                 │                │  └ <built-in method exec_>
#     │  │                 │                └ <PyQt5.QtCore.QEventLoop object at 0x00000151D411BA60>
#     │  │                 └ <PyQt5.QtCore.QEventLoop object at 0x00000151D411BA60>
#     │  └ <built-in method exec>
#     └ <PyQt5.QtCore.QEventLoop object at 0x00000151D411BA60>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\napari_assistant\_gui\_Assistant.py", line 200, in _on_item_clicked
#     self._activate(CATEGORIES.get(item.text()))
#     │    │         │          │   │    └ <built-in method text>
#     │    │         │          │   └ <PyQt5.QtWidgets.QListWidgetItem object at 0x00000151D412AAF0>
#     │    │         │          └ <method 'get' of 'dict' objects>
#     │    │         └ {'Remove noise': Category(name='Remove noise', description='Remove noise from images, e.g. by local averaging and blurring.',...
#     │    └ <function Assistant._activate at 0x00000151E439C940>
#     └ <napari_assistant._gui._Assistant.Assistant object at 0x00000151E3486790>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\napari_assistant\_gui\_Assistant.py", line 234, in _activate
#     layer = gui()
#             └ <FunctionGui do_label(*, input0: napari.layers.base.base.Layer = <Image layer 'C1-Reunion Edwin 160223.lif - M156 40x s3 Hopx...
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\magicgui\widgets\_function_gui.py", line 331, in __call__
#     value = self._function(*bound.args, **bound.kwargs)
#             │    │          │     │       │     └ <property object at 0x00000151C52C85E0>
#             │    │          │     │       └ <BoundArguments (input0=<Image layer 'C1-Reunion Edwin 160223.lif - M156 40x s3 Hopx Sox2' at 0x151eba848e0>, op_name='Object...
#             │    │          │     └ <property object at 0x00000151C52C8590>
#             │    │          └ <BoundArguments (input0=<Image layer 'C1-Reunion Edwin 160223.lif - M156 40x s3 Hopx Sox2' at 0x151eba848e0>, op_name='Object...
#             │    └ <function make_gui_for_category.<locals>.gui_function at 0x00000151D412A5E0>
#             └ <FunctionGui do_label(*, input0: napari.layers.base.base.Layer = <Image layer 'C1-Reunion Edwin 160223.lif - M156 40x s3 Hopx...
#
# > File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\napari_assistant\_gui\_category_widget.py", line 431, in gui_function
#     result, used_args = call_op(op_name, inputs, t_position, viewer, **kwargs)
#                         │       │        │       │           │         └ {'x': 2.0, 'y': 2.0, 'z': 0.0, 'u': 0.0, 'v': 0.0, 'w': 0.0, 'w1': 0.0, 'w2': 0.0, 'w3': 0.0, 'w4': 0.0, 'a': False, 'b': Fal...
#                         │       │        │       │           └ Viewer(axes=Axes(visible=False, labels=True, colored=True, dashed=False, arrows=True), camera=Camera(center=(0.0, 511.5, 511....
#                         │       │        │       └ None
#                         │       │        └ [<Image layer 'C1-Reunion Edwin 160223.lif - M156 40x s3 Hopx Sox2' at 0x151eba848e0>]
#                         │       └ 'Object segmentation (apply pretrained, APOC)'
#                         └ <function call_op at 0x00000151E4394D30>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\napari_assistant\_gui\_category_widget.py", line 210, in call_op
#     gpu_out = cle_function(*args, **kwargs)
#               │             │       └ {'viewer': Viewer(axes=Axes(visible=False, labels=True, colored=True, dashed=False, arrows=True), camera=Camera(center=(0.0, ...
#               │             └ [array([[[ 5,  6,  5, ..., 13, 12, 12],
#               │                       [ 7,  7,  5, ..., 10, 10, 10],
#               │                       [ 5,  6,  6, ..., 11,  7,  6],
#               │                      ...
#               └ <function Apply_object_segmentation at 0x00000151D3FDC040>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\napari_time_slicer\__init__.py", line 61, in worker_function
#     result = function(*bound.args, **bound.kwargs)
#              │         │     │       │     └ <property object at 0x00000151C52C85E0>
#              │         │     │       └ <BoundArguments (image=array([[[ 5,  6,  5, ..., 13, 12, 12],
#              │         │     │                 [ 7,  7,  5, ..., 10, 10, 10],
#              │         │     │                 [ 5,  6,  6, ......
#              │         │     └ <property object at 0x00000151C52C8590>
#              │         └ <BoundArguments (image=array([[[ 5,  6,  5, ..., 13, 12, 12],
#              │                   [ 7,  7,  5, ..., 10, 10, 10],
#              │                   [ 5,  6,  6, ......
#              └ <function Apply_object_segmentation at 0x00000151D3FDBF70>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\napari_accelerated_pixel_and_object_classification\_function.py", line 151, in Apply_object_segmentation
#     result = clf.predict(image=[image])
#              │   │              └ array([[[ 5,  6,  5, ..., 13, 12, 12],
#              │   │                        [ 7,  7,  5, ..., 10, 10, 10],
#              │   │                        [ 5,  6,  6, ..., 11,  7,  6],
#              │   │                        ...
#              │   └ <function ObjectSegmenter.predict at 0x00000151CDA16AF0>
#              └ Classifier type: ObjectSegmenter
#                --- Random forest info ---
#                Used features for training: Custom/unkown
#                Ground truth dimensions...
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\apoc\_object_segmenter.py", line 66, in predict
#     result = super().predict(features=features, image=image)
#                                       │               └ [array([[[ 5,  6,  5, ..., 13, 12, 12],
#                                       │                         [ 7,  7,  5, ..., 10, 10, 10],
#                                       │                         [ 5,  6,  6, ..., 11,  7,  6],
#                                       │                        ...
#                                       └ None
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\apoc\_pixel_classifier.py", line 146, in predict
#     output = cle.create_labels_like(features[0])
#              │   │                  └ []
#              │   └ <function create_labels_like at 0x00000151CD346940>
#              └ <module 'pyclesperanto_prototype' from 'C:\\Users\\elful\\miniconda3\\envs\\devbio-napari-env\\lib\\site-packages\\pyclespera...
#
# IndexError: list index out of range
# C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\napari_assistant\_gui\_category_widget.py:436: UserWarning: Operation failed. Please check input parameters and documentation.
# cannot unpack non-iterable NoneType object
#   warnings.warn("Operation failed. Please check input parameters and documentation.\n" + str(e))
# 2023-06-30 15:03:28.922 | ERROR    | napari_assistant._gui._category_widget:gui_function:431 - An error has been caught in function 'gui_function', process 'MainProcess' (37388), thread 'MainThread' (22712):
# Traceback (most recent call last):
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#            │         │     └ {'__name__': '__main__', '__doc__': 'Entry point for launching an IPython kernel.\n\nThis is separate from the ipykernel pack...
#            │         └ <code object <module> at 0x00000151C33849D0, file "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\ipykern...
#            └ <function _run_code at 0x00000151C3572C10>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#          │     └ {'__name__': '__main__', '__doc__': 'Entry point for launching an IPython kernel.\n\nThis is separate from the ipykernel pack...
#          └ <code object <module> at 0x00000151C33849D0, file "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\ipykern...
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#     │   └ <bound method Application.launch_instance of <class 'ipykernel.kernelapp.IPKernelApp'>>
#     └ <module 'ipykernel.kernelapp' from 'C:\\Users\\elful\\miniconda3\\envs\\devbio-napari-env\\lib\\site-packages\\ipykernel\\ker...
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#     │   └ <function IPKernelApp.start at 0x00000151C7A8A280>
#     └ <ipykernel.kernelapp.IPKernelApp object at 0x00000151C31DB0A0>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\ipykernel\kernelapp.py", line 725, in start
#     self.io_loop.start()
#     │    │       └ <function BaseAsyncIOLoop.start at 0x00000151C7A8ADC0>
#     │    └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x00000151C7ADC340>
#     └ <ipykernel.kernelapp.IPKernelApp object at 0x00000151C31DB0A0>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\tornado\platform\asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#     │    │            └ <function BaseEventLoop.run_forever at 0x00000151C533DA60>
#     │    └ <_WindowsSelectorEventLoop running=True closed=False debug=False>
#     └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x00000151C7ADC340>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\asyncio\base_events.py", line 601, in run_forever
#     self._run_once()
#     │    └ <function BaseEventLoop._run_once at 0x00000151C53405E0>
#     └ <_WindowsSelectorEventLoop running=True closed=False debug=False>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\asyncio\base_events.py", line 1905, in _run_once
#     handle._run()
#     │      └ <function Handle._run at 0x00000151C52CFAF0>
#     └ <TimerHandle when=778646.5009999275 IOLoop._run_callback(functools.par...0151C7AD4940>))>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#     │    │            │    │           │    └ <member '_args' of 'Handle' objects>
#     │    │            │    │           └ <TimerHandle when=778646.5009999275 IOLoop._run_callback(functools.par...0151C7AD4940>))>
#     │    │            │    └ <member '_callback' of 'Handle' objects>
#     │    │            └ <TimerHandle when=778646.5009999275 IOLoop._run_callback(functools.par...0151C7AD4940>))>
#     │    └ <member '_context' of 'Handle' objects>
#     └ <TimerHandle when=778646.5009999275 IOLoop._run_callback(functools.par...0151C7AD4940>))>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\tornado\ioloop.py", line 738, in _run_callback
#     ret = callback()
#           └ functools.partial(<function Kernel.enter_eventloop.<locals>.advance_eventloop at 0x00000151C7AD4940>)
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\ipykernel\kernelbase.py", line 458, in advance_eventloop
#     eventloop(self)
#     │         └ <ipykernel.ipkernel.IPythonKernel object at 0x00000151C7AD6E50>
#     └ <function loop_qt at 0x00000151C7A693A0>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\ipykernel\eventloops.py", line 128, in loop_qt
#     el.exec() if hasattr(el, 'exec') else el.exec_()
#     │  │                 │                │  └ <built-in method exec_>
#     │  │                 │                └ <PyQt5.QtCore.QEventLoop object at 0x00000151D411BA60>
#     │  │                 └ <PyQt5.QtCore.QEventLoop object at 0x00000151D411BA60>
#     │  └ <built-in method exec>
#     └ <PyQt5.QtCore.QEventLoop object at 0x00000151D411BA60>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\magicgui\widgets\bases\_value_widget.py", line 65, in _on_value_change
#     self.changed.emit(value)
#     │    │       │    └ '"C:\\Users\\elful\\Documents\\Analysis_Pipelines\\CI2A\\ObjectSegmenter.cl"'
#     │    │       └ <function SignalInstance.emit at 0x00000151D0BF8790>
#     │    └ <SignalInstance 'changed' on LineEdit(value='"C:\\Users\\elful\\Documents\\Analysis_Pipelines\\CI2A\\ObjectSegmenter.cl"', an...
#     └ LineEdit(value='"C:\\Users\\elful\\Documents\\Analysis_Pipelines\\CI2A\\ObjectSegmenter.cl"', annotation=<class 'str'>, name=...
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\psygnal\_signal.py", line 927, in emit
#     self._run_emit_loop(args)
#     │    │              └ ('"C:\\Users\\elful\\Documents\\Analysis_Pipelines\\CI2A\\ObjectSegmenter.cl"',)
#     │    └ <function SignalInstance._run_emit_loop at 0x00000151D0BF88B0>
#     └ <SignalInstance 'changed' on LineEdit(value='"C:\\Users\\elful\\Documents\\Analysis_Pipelines\\CI2A\\ObjectSegmenter.cl"', an...
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\psygnal\_signal.py", line 972, in _run_emit_loop
#     caller.cb(args)
#     │      │  └ ('"C:\\Users\\elful\\Documents\\Analysis_Pipelines\\CI2A\\ObjectSegmenter.cl"',)
#     │      └ <function _StrongFunction.cb at 0x00000151D0BE6CA0>
#     └ <psygnal._weak_callback._StrongFunction object at 0x00000151EFDE16D0>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\psygnal\_weak_callback.py", line 268, in cb
#     self._f(*self._args, *args, **self._kwargs)
#     │    │   │    │       │       │    └ {}
#     │    │   │    │       │       └ <psygnal._weak_callback._StrongFunction object at 0x00000151EFDE16D0>
#     │    │   │    │       └ ()
#     │    │   │    └ ()
#     │    │   └ <psygnal._weak_callback._StrongFunction object at 0x00000151EFDE16D0>
#     │    └ <function ContainerWidget.insert.<locals>.<lambda> at 0x00000151EFDE0310>
#     └ <psygnal._weak_callback._StrongFunction object at 0x00000151EFDE16D0>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\magicgui\widgets\bases\_container_widget.py", line 198, in <lambda>
#     widget.changed.connect(lambda: self.changed.emit(self))
#                                    │    │       │    └ <FunctionGui do_label(*, input0: napari.layers.base.base.Layer = <Image layer 'C1-Reunion Edwin 160223.lif - M156 40x s3 Hopx...
#                                    │    │       └ <function SignalInstance.emit at 0x00000151D0BF8790>
#                                    │    └ <SignalInstance 'changed' on <FunctionGui do_label(*, input0: napari.layers.base.base.Layer = <Image layer 'C1-Reunion Edwin ...
#                                    └ <FunctionGui do_label(*, input0: napari.layers.base.base.Layer = <Image layer 'C1-Reunion Edwin 160223.lif - M156 40x s3 Hopx...
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\psygnal\_signal.py", line 927, in emit
#     self._run_emit_loop(args)
#     │    │              └ (<FunctionGui do_label(*, input0: napari.layers.base.base.Layer = <Image layer 'C1-Reunion Edwin 160223.lif - M156 40x s3 Hop...
#     │    └ <function SignalInstance._run_emit_loop at 0x00000151D0BF88B0>
#     └ <SignalInstance 'changed' on <FunctionGui do_label(*, input0: napari.layers.base.base.Layer = <Image layer 'C1-Reunion Edwin ...
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\psygnal\_signal.py", line 972, in _run_emit_loop
#     caller.cb(args)
#     │      │  └ (<FunctionGui do_label(*, input0: napari.layers.base.base.Layer = <Image layer 'C1-Reunion Edwin 160223.lif - M156 40x s3 Hop...
#     │      └ <function _WeakMethod.cb at 0x00000151D0BF4040>
#     └ <psygnal._weak_callback._WeakMethod object at 0x00000151EFDEFA30>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\psygnal\_weak_callback.py", line 344, in cb
#     func(obj, *self._args, *args, **self._kwargs)
#     │    │     │    │       │       │    └ {}
#     │    │     │    │       │       └ <psygnal._weak_callback._WeakMethod object at 0x00000151EFDEFA30>
#     │    │     │    │       └ ()
#     │    │     │    └ ()
#     │    │     └ <psygnal._weak_callback._WeakMethod object at 0x00000151EFDEFA30>
#     │    └ <FunctionGui do_label(*, input0: napari.layers.base.base.Layer = <Image layer 'C1-Reunion Edwin 160223.lif - M156 40x s3 Hopx...
#     └ <function FunctionGui._on_change at 0x00000151D0C6A8B0>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\magicgui\widgets\_function_gui.py", line 250, in _on_change
#     self()
#     └ <FunctionGui do_label(*, input0: napari.layers.base.base.Layer = <Image layer 'C1-Reunion Edwin 160223.lif - M156 40x s3 Hopx...
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\magicgui\widgets\_function_gui.py", line 331, in __call__
#     value = self._function(*bound.args, **bound.kwargs)
#             │    │          │     │       │     └ <property object at 0x00000151C52C85E0>
#             │    │          │     │       └ <BoundArguments (input0=<Image layer 'C1-Reunion Edwin 160223.lif - M156 40x s3 Hopx Sox2' at 0x151eba848e0>, op_name='Object...
#             │    │          │     └ <property object at 0x00000151C52C8590>
#             │    │          └ <BoundArguments (input0=<Image layer 'C1-Reunion Edwin 160223.lif - M156 40x s3 Hopx Sox2' at 0x151eba848e0>, op_name='Object...
#             │    └ <function make_gui_for_category.<locals>.gui_function at 0x00000151D412A5E0>
#             └ <FunctionGui do_label(*, input0: napari.layers.base.base.Layer = <Image layer 'C1-Reunion Edwin 160223.lif - M156 40x s3 Hopx...
#
# > File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\napari_assistant\_gui\_category_widget.py", line 431, in gui_function
#     result, used_args = call_op(op_name, inputs, t_position, viewer, **kwargs)
#                         │       │        │       │           │         └ {'x': 2.0, 'y': 2.0, 'z': 0.0, 'u': 0.0, 'v': 0.0, 'w': 0.0, 'w1': 0.0, 'w2': 0.0, 'w3': 0.0, 'w4': 0.0, 'a': False, 'b': Fal...
#                         │       │        │       │           └ Viewer(axes=Axes(visible=False, labels=True, colored=True, dashed=False, arrows=True), camera=Camera(center=(0.0, 511.5, 511....
#                         │       │        │       └ None
#                         │       │        └ [<Image layer 'C1-Reunion Edwin 160223.lif - M156 40x s3 Hopx Sox2' at 0x151eba848e0>]
#                         │       └ 'Object segmentation (apply pretrained, APOC)'
#                         └ <function call_op at 0x00000151E4394D30>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\napari_assistant\_gui\_category_widget.py", line 210, in call_op
#     gpu_out = cle_function(*args, **kwargs)
#               │             │       └ {'viewer': Viewer(axes=Axes(visible=False, labels=True, colored=True, dashed=False, arrows=True), camera=Camera(center=(0.0, ...
#               │             └ [array([[[ 5,  6,  5, ..., 13, 12, 12],
#               │                       [ 7,  7,  5, ..., 10, 10, 10],
#               │                       [ 5,  6,  6, ..., 11,  7,  6],
#               │                      ...
#               └ <function Apply_object_segmentation at 0x00000151D3FDC040>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\napari_time_slicer\__init__.py", line 61, in worker_function
#     result = function(*bound.args, **bound.kwargs)
#              │         │     │       │     └ <property object at 0x00000151C52C85E0>
#              │         │     │       └ <BoundArguments (image=array([[[ 5,  6,  5, ..., 13, 12, 12],
#              │         │     │                 [ 7,  7,  5, ..., 10, 10, 10],
#              │         │     │                 [ 5,  6,  6, ......
#              │         │     └ <property object at 0x00000151C52C8590>
#              │         └ <BoundArguments (image=array([[[ 5,  6,  5, ..., 13, 12, 12],
#              │                   [ 7,  7,  5, ..., 10, 10, 10],
#              │                   [ 5,  6,  6, ......
#              └ <function Apply_object_segmentation at 0x00000151D3FDBF70>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\napari_accelerated_pixel_and_object_classification\_function.py", line 151, in Apply_object_segmentation
#     result = clf.predict(image=[image])
#              │   │              └ array([[[ 5,  6,  5, ..., 13, 12, 12],
#              │   │                        [ 7,  7,  5, ..., 10, 10, 10],
#              │   │                        [ 5,  6,  6, ..., 11,  7,  6],
#              │   │                        ...
#              │   └ <function ObjectSegmenter.predict at 0x00000151CDA16AF0>
#              └ Classifier type: ObjectSegmenter
#                --- Random forest info ---
#                Used features for training: Custom/unkown
#                Ground truth dimensions...
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\apoc\_object_segmenter.py", line 66, in predict
#     result = super().predict(features=features, image=image)
#                                       │               └ [array([[[ 5,  6,  5, ..., 13, 12, 12],
#                                       │                         [ 7,  7,  5, ..., 10, 10, 10],
#                                       │                         [ 5,  6,  6, ..., 11,  7,  6],
#                                       │                        ...
#                                       └ None
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\apoc\_pixel_classifier.py", line 146, in predict
#     output = cle.create_labels_like(features[0])
#              │   │                  └ []
#              │   └ <function create_labels_like at 0x00000151CD346940>
#              └ <module 'pyclesperanto_prototype' from 'C:\\Users\\elful\\miniconda3\\envs\\devbio-napari-env\\lib\\site-packages\\pyclespera...
#
# IndexError: list index out of range
# C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\napari_assistant\_gui\_category_widget.py:436: UserWarning: Operation failed. Please check input parameters and documentation.
# cannot unpack non-iterable NoneType object
#   warnings.warn("Operation failed. Please check input parameters and documentation.\n" + str(e))
# 2023-06-30 15:03:30.601 | ERROR    | napari_assistant._gui._category_widget:gui_function:431 - An error has been caught in function 'gui_function', process 'MainProcess' (37388), thread 'MainThread' (22712):
# Traceback (most recent call last):
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#            │         │     └ {'__name__': '__main__', '__doc__': 'Entry point for launching an IPython kernel.\n\nThis is separate from the ipykernel pack...
#            │         └ <code object <module> at 0x00000151C33849D0, file "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\ipykern...
#            └ <function _run_code at 0x00000151C3572C10>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#          │     └ {'__name__': '__main__', '__doc__': 'Entry point for launching an IPython kernel.\n\nThis is separate from the ipykernel pack...
#          └ <code object <module> at 0x00000151C33849D0, file "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\ipykern...
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#     │   └ <bound method Application.launch_instance of <class 'ipykernel.kernelapp.IPKernelApp'>>
#     └ <module 'ipykernel.kernelapp' from 'C:\\Users\\elful\\miniconda3\\envs\\devbio-napari-env\\lib\\site-packages\\ipykernel\\ker...
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#     │   └ <function IPKernelApp.start at 0x00000151C7A8A280>
#     └ <ipykernel.kernelapp.IPKernelApp object at 0x00000151C31DB0A0>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\ipykernel\kernelapp.py", line 725, in start
#     self.io_loop.start()
#     │    │       └ <function BaseAsyncIOLoop.start at 0x00000151C7A8ADC0>
#     │    └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x00000151C7ADC340>
#     └ <ipykernel.kernelapp.IPKernelApp object at 0x00000151C31DB0A0>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\tornado\platform\asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#     │    │            └ <function BaseEventLoop.run_forever at 0x00000151C533DA60>
#     │    └ <_WindowsSelectorEventLoop running=True closed=False debug=False>
#     └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x00000151C7ADC340>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\asyncio\base_events.py", line 601, in run_forever
#     self._run_once()
#     │    └ <function BaseEventLoop._run_once at 0x00000151C53405E0>
#     └ <_WindowsSelectorEventLoop running=True closed=False debug=False>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\asyncio\base_events.py", line 1905, in _run_once
#     handle._run()
#     │      └ <function Handle._run at 0x00000151C52CFAF0>
#     └ <TimerHandle when=778646.5009999275 IOLoop._run_callback(functools.par...0151C7AD4940>))>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#     │    │            │    │           │    └ <member '_args' of 'Handle' objects>
#     │    │            │    │           └ <TimerHandle when=778646.5009999275 IOLoop._run_callback(functools.par...0151C7AD4940>))>
#     │    │            │    └ <member '_callback' of 'Handle' objects>
#     │    │            └ <TimerHandle when=778646.5009999275 IOLoop._run_callback(functools.par...0151C7AD4940>))>
#     │    └ <member '_context' of 'Handle' objects>
#     └ <TimerHandle when=778646.5009999275 IOLoop._run_callback(functools.par...0151C7AD4940>))>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\tornado\ioloop.py", line 738, in _run_callback
#     ret = callback()
#           └ functools.partial(<function Kernel.enter_eventloop.<locals>.advance_eventloop at 0x00000151C7AD4940>)
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\ipykernel\kernelbase.py", line 458, in advance_eventloop
#     eventloop(self)
#     │         └ <ipykernel.ipkernel.IPythonKernel object at 0x00000151C7AD6E50>
#     └ <function loop_qt at 0x00000151C7A693A0>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\ipykernel\eventloops.py", line 128, in loop_qt
#     el.exec() if hasattr(el, 'exec') else el.exec_()
#     │  │                 │                │  └ <built-in method exec_>
#     │  │                 │                └ <PyQt5.QtCore.QEventLoop object at 0x00000151D411BA60>
#     │  │                 └ <PyQt5.QtCore.QEventLoop object at 0x00000151D411BA60>
#     │  └ <built-in method exec>
#     └ <PyQt5.QtCore.QEventLoop object at 0x00000151D411BA60>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\magicgui\widgets\bases\_value_widget.py", line 65, in _on_value_change
#     self.changed.emit(value)
#     │    │       │    └ '"C:\\Users\\elful\\Documents\\Analysis_Pipelines\\CI2A\\ObjectSegmenter.cl'
#     │    │       └ <function SignalInstance.emit at 0x00000151D0BF8790>
#     │    └ <SignalInstance 'changed' on LineEdit(value='"C:\\Users\\elful\\Documents\\Analysis_Pipelines\\CI2A\\ObjectSegmenter.cl', ann...
#     └ LineEdit(value='"C:\\Users\\elful\\Documents\\Analysis_Pipelines\\CI2A\\ObjectSegmenter.cl', annotation=<class 'str'>, name='k')
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\psygnal\_signal.py", line 927, in emit
#     self._run_emit_loop(args)
#     │    │              └ ('"C:\\Users\\elful\\Documents\\Analysis_Pipelines\\CI2A\\ObjectSegmenter.cl',)
#     │    └ <function SignalInstance._run_emit_loop at 0x00000151D0BF88B0>
#     └ <SignalInstance 'changed' on LineEdit(value='"C:\\Users\\elful\\Documents\\Analysis_Pipelines\\CI2A\\ObjectSegmenter.cl', ann...
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\psygnal\_signal.py", line 972, in _run_emit_loop
#     caller.cb(args)
#     │      │  └ ('"C:\\Users\\elful\\Documents\\Analysis_Pipelines\\CI2A\\ObjectSegmenter.cl',)
#     │      └ <function _StrongFunction.cb at 0x00000151D0BE6CA0>
#     └ <psygnal._weak_callback._StrongFunction object at 0x00000151EFDE16D0>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\psygnal\_weak_callback.py", line 268, in cb
#     self._f(*self._args, *args, **self._kwargs)
#     │    │   │    │       │       │    └ {}
#     │    │   │    │       │       └ <psygnal._weak_callback._StrongFunction object at 0x00000151EFDE16D0>
#     │    │   │    │       └ ()
#     │    │   │    └ ()
#     │    │   └ <psygnal._weak_callback._StrongFunction object at 0x00000151EFDE16D0>
#     │    └ <function ContainerWidget.insert.<locals>.<lambda> at 0x00000151EFDE0310>
#     └ <psygnal._weak_callback._StrongFunction object at 0x00000151EFDE16D0>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\magicgui\widgets\bases\_container_widget.py", line 198, in <lambda>
#     widget.changed.connect(lambda: self.changed.emit(self))
#                                    │    │       │    └ <FunctionGui do_label(*, input0: napari.layers.base.base.Layer = <Image layer 'C1-Reunion Edwin 160223.lif - M156 40x s3 Hopx...
#                                    │    │       └ <function SignalInstance.emit at 0x00000151D0BF8790>
#                                    │    └ <SignalInstance 'changed' on <FunctionGui do_label(*, input0: napari.layers.base.base.Layer = <Image layer 'C1-Reunion Edwin ...
#                                    └ <FunctionGui do_label(*, input0: napari.layers.base.base.Layer = <Image layer 'C1-Reunion Edwin 160223.lif - M156 40x s3 Hopx...
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\psygnal\_signal.py", line 927, in emit
#     self._run_emit_loop(args)
#     │    │              └ (<FunctionGui do_label(*, input0: napari.layers.base.base.Layer = <Image layer 'C1-Reunion Edwin 160223.lif - M156 40x s3 Hop...
#     │    └ <function SignalInstance._run_emit_loop at 0x00000151D0BF88B0>
#     └ <SignalInstance 'changed' on <FunctionGui do_label(*, input0: napari.layers.base.base.Layer = <Image layer 'C1-Reunion Edwin ...
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\psygnal\_signal.py", line 972, in _run_emit_loop
#     caller.cb(args)
#     │      │  └ (<FunctionGui do_label(*, input0: napari.layers.base.base.Layer = <Image layer 'C1-Reunion Edwin 160223.lif - M156 40x s3 Hop...
#     │      └ <function _WeakMethod.cb at 0x00000151D0BF4040>
#     └ <psygnal._weak_callback._WeakMethod object at 0x00000151EFDEFA30>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\psygnal\_weak_callback.py", line 344, in cb
#     func(obj, *self._args, *args, **self._kwargs)
#     │    │     │    │       │       │    └ {}
#     │    │     │    │       │       └ <psygnal._weak_callback._WeakMethod object at 0x00000151EFDEFA30>
#     │    │     │    │       └ ()
#     │    │     │    └ ()
#     │    │     └ <psygnal._weak_callback._WeakMethod object at 0x00000151EFDEFA30>
#     │    └ <FunctionGui do_label(*, input0: napari.layers.base.base.Layer = <Image layer 'C1-Reunion Edwin 160223.lif - M156 40x s3 Hopx...
#     └ <function FunctionGui._on_change at 0x00000151D0C6A8B0>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\magicgui\widgets\_function_gui.py", line 250, in _on_change
#     self()
#     └ <FunctionGui do_label(*, input0: napari.layers.base.base.Layer = <Image layer 'C1-Reunion Edwin 160223.lif - M156 40x s3 Hopx...
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\magicgui\widgets\_function_gui.py", line 331, in __call__
#     value = self._function(*bound.args, **bound.kwargs)
#             │    │          │     │       │     └ <property object at 0x00000151C52C85E0>
#             │    │          │     │       └ <BoundArguments (input0=<Image layer 'C1-Reunion Edwin 160223.lif - M156 40x s3 Hopx Sox2' at 0x151eba848e0>, op_name='Object...
#             │    │          │     └ <property object at 0x00000151C52C8590>
#             │    │          └ <BoundArguments (input0=<Image layer 'C1-Reunion Edwin 160223.lif - M156 40x s3 Hopx Sox2' at 0x151eba848e0>, op_name='Object...
#             │    └ <function make_gui_for_category.<locals>.gui_function at 0x00000151D412A5E0>
#             └ <FunctionGui do_label(*, input0: napari.layers.base.base.Layer = <Image layer 'C1-Reunion Edwin 160223.lif - M156 40x s3 Hopx...
#
# > File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\napari_assistant\_gui\_category_widget.py", line 431, in gui_function
#     result, used_args = call_op(op_name, inputs, t_position, viewer, **kwargs)
#                         │       │        │       │           │         └ {'x': 2.0, 'y': 2.0, 'z': 0.0, 'u': 0.0, 'v': 0.0, 'w': 0.0, 'w1': 0.0, 'w2': 0.0, 'w3': 0.0, 'w4': 0.0, 'a': False, 'b': Fal...
#                         │       │        │       │           └ Viewer(axes=Axes(visible=False, labels=True, colored=True, dashed=False, arrows=True), camera=Camera(center=(0.0, 511.5, 511....
#                         │       │        │       └ None
#                         │       │        └ [<Image layer 'C1-Reunion Edwin 160223.lif - M156 40x s3 Hopx Sox2' at 0x151eba848e0>]
#                         │       └ 'Object segmentation (apply pretrained, APOC)'
#                         └ <function call_op at 0x00000151E4394D30>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\napari_assistant\_gui\_category_widget.py", line 210, in call_op
#     gpu_out = cle_function(*args, **kwargs)
#               │             │       └ {'viewer': Viewer(axes=Axes(visible=False, labels=True, colored=True, dashed=False, arrows=True), camera=Camera(center=(0.0, ...
#               │             └ [array([[[ 5,  6,  5, ..., 13, 12, 12],
#               │                       [ 7,  7,  5, ..., 10, 10, 10],
#               │                       [ 5,  6,  6, ..., 11,  7,  6],
#               │                      ...
#               └ <function Apply_object_segmentation at 0x00000151D3FDC040>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\napari_time_slicer\__init__.py", line 61, in worker_function
#     result = function(*bound.args, **bound.kwargs)
#              │         │     │       │     └ <property object at 0x00000151C52C85E0>
#              │         │     │       └ <BoundArguments (image=array([[[ 5,  6,  5, ..., 13, 12, 12],
#              │         │     │                 [ 7,  7,  5, ..., 10, 10, 10],
#              │         │     │                 [ 5,  6,  6, ......
#              │         │     └ <property object at 0x00000151C52C8590>
#              │         └ <BoundArguments (image=array([[[ 5,  6,  5, ..., 13, 12, 12],
#              │                   [ 7,  7,  5, ..., 10, 10, 10],
#              │                   [ 5,  6,  6, ......
#              └ <function Apply_object_segmentation at 0x00000151D3FDBF70>
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\napari_accelerated_pixel_and_object_classification\_function.py", line 151, in Apply_object_segmentation
#     result = clf.predict(image=[image])
#              │   │              └ array([[[ 5,  6,  5, ..., 13, 12, 12],
#              │   │                        [ 7,  7,  5, ..., 10, 10, 10],
#              │   │                        [ 5,  6,  6, ..., 11,  7,  6],
#              │   │                        ...
#              │   └ <function ObjectSegmenter.predict at 0x00000151CDA16AF0>
#              └ Classifier type: ObjectSegmenter
#                --- Random forest info ---
#                Used features for training: Custom/unkown
#                Ground truth dimensions...
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\apoc\_object_segmenter.py", line 66, in predict
#     result = super().predict(features=features, image=image)
#                                       │               └ [array([[[ 5,  6,  5, ..., 13, 12, 12],
#                                       │                         [ 7,  7,  5, ..., 10, 10, 10],
#                                       │                         [ 5,  6,  6, ..., 11,  7,  6],
#                                       │                        ...
#                                       └ None
#
#   File "C:\Users\elful\miniconda3\envs\devbio-napari-env\lib\site-packages\apoc\_pixel_classifier.py", line 146, in predict
#     output = cle.create_labels_like(features[0])
#              │   │                  └ []
#              │   └ <function create_labels_like at 0x00000151CD346940>
#              └ <module 'pyclesperanto_prototype' from 'C:\\Users\\elful\\miniconda3\\envs\\devbio-napari-env\\lib\\site-packages\\pyclespera...
#
# IndexError: list index out of range

# %% [markdown]
# ## Apply object segmentation

# %%
image2_O = napari_accelerated_pixel_and_object_classification.Apply_object_segmentation(
    image0_C, image1_CP)
viewer.add_labels(
    image2_O, name='Result of Object segmentation (apply pretrained, APOC)')
napari.utils.nbscreenshot(viewer)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 image2_O = napari_accelerated_pixel_and_object_classification.Apply_object_segmentation(
#       2     image0_C, image1_CP)
#       3 viewer.add_labels(
#       4     image2_O, name='Result of Object segmentation (apply pretrained, APOC)')
#       5 napari.utils.nbscreenshot(viewer)
#
# AttributeError: module 'napari_accelerated_pixel_and_object_classification' has no attribute 'Apply_object_segmentation'
