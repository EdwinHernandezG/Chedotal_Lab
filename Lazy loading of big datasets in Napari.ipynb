# %% [markdown]
# # Lazy loading in Napari for big Datasets

# %% [markdown]
# Sometimes the 3D rendering in Napari is really slow because of the size of the dataset, and is even worst if we have a big set of labels like the ones that came from cell segmentation in lightsheet datasets because we can find millions of objects that requires a 32-bits label image that can exceed the size of the raw dataset itself.
#
# For this reason, we develop this Jupyter Notebook to facilitate the visualization of this images, using a dask array of our zarr images for the lazy loading of the image.

# %% [markdown]
# ## Setting up dependencies

# %%
import time
import os
import glob
import dask.array as da
import numpy as np
import zarr as zr
from tifffile import imread, imwrite
from aicsimageio import AICSImage
from aicsimageio.readers import BioformatsReader

# %% [markdown]
# ## Start the Dask dashboard

# %%
from dask.distributed import Client

client = Client()
client

# %% [markdown]
# In this example, we assume that we are going to visualize a dataset together with the coresspondant labels, you can add more channels or datasets as you want. In Napari is better to  import each channel as independent layer. In this example we are going to visualize two nuclear factors, SOX9 and OCT4 with it's labels generated with Stardist.

# %%
Images = 'G:\Stardist_results'

# %%
import napari
from napari.utils import nbscreenshot
#import nest_asyncio
#nest_asyncio.apply()

v = napari.Viewer()
for img in os.listdir(Images):
    short_name = os.path.splitext(img)
    
    
    
    if img.endswith("_lb.tif"):
        store = AICSImage(Images+"/"+img, reader=BioformatsReader)
        store.dask_data
        store.xarray_dask_data
        
        v.add_labels(store.dask_data, name='label '+str(img[0]))
        
        print(os.path.join(Images, img)+' is in Napari')
        
        continue
        
    else:
        store = AICSImage(Images+"/"+img, reader=BioformatsReader)
        store.dask_data
        store.xarray_dask_data
        
        v.add_image(store.dask_data, name='image '+str(img[0]), contrast_limits=[0,65535])
        
        print(os.path.join(Images, img)+' is in Napari')
        
        continue

# %% [markdown]
# ## Load one by one

# %%
import napari
from napari.utils import nbscreenshot

v = napari.Viewer()

img = r"G:\Stardist_results\EH3574_Oct4.tif"
short_name = os.path.splitext(img)

storeim = AICSImage(img, reader=BioformatsReader)
image= storeim.dask_data
storeim.xarray_dask_data
        
v.add_image(image, name='label '+str(short_name[0]))
        
print(img+' is in Napari')
print(image.shape, image.size, image.dtype)
# Out:
# C:\Users\Linux\.conda\envs\bio11\lib\site-packages\napari_tools_menu\__init__.py:168: FutureWarning: Public access to Window.qt_viewer is deprecated and will be removed in
# v0.5.0. It is considered an "implementation detail" of the napari
# application, not part of the napari viewer model. If your use case
# requires access to qt_viewer, please open an issue to discuss.
#   self.tools_menu = ToolsMenu(self, self.qt_viewer.viewer)
# G:\Stardist_results\EH3574_Oct4.tif is in Napari
# (1053, 1, 1, 7177, 4117) 31113737577 uint16

# %%
lbl = r"G:\Stardist_results\EH3574_Oct4_lb.tif"
short_namel = os.path.splitext(lbl)

storelb = AICSImage(lbl, reader=BioformatsReader)
labels = storelb.dask_data
storelb.xarray_dask_data
        
v.add_labels(labels, name='label '+str(short_namel[0]))
        
print(lbl+' is in Napari')
print(labels.shape, labels.size, labels.dtype)
# Out:
# G:\Stardist_results\EH3574_Oct4_lb.tif is in Napari
# (1053, 1, 1, 7177, 4117) 1048966505 int32
# exception calling callback for <Future at 0x228e7b6fdc0 state=finished raised java.lang.IllegalArgumentException>
# Traceback (most recent call last):
#   File "ImageReader.java", line 539, in loci.formats.ImageReader.getIndex
#   File "FormatReader.java", line 1105, in loci.formats.FormatReader.getIndex
#   File "FormatTools.java", line 408, in loci.formats.FormatTools.getIndex
#   File "FormatTools.java", line 456, in loci.formats.FormatTools.getIndex
# Exception: Java Exception
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\Linux\.conda\envs\bio11\lib\concurrent\futures\_base.py", line 330, in _invoke_callbacks
#     callback(self)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\napari\components\experimental\chunk\_pool.py", line 153, in _on_done
#     request = self._get_request(future)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\napari\components\experimental\chunk\_pool.py", line 189, in _get_request
#     return future.result()
#   File "C:\Users\Linux\.conda\envs\bio11\lib\concurrent\futures\_base.py", line 439, in result
#     return self.__get_result()
#   File "C:\Users\Linux\.conda\envs\bio11\lib\concurrent\futures\_base.py", line 391, in __get_result
#     raise self._exception
#   File "C:\Users\Linux\.conda\envs\bio11\lib\concurrent\futures\thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\napari\components\experimental\chunk\_pool.py", line 223, in _chunk_loader_worker
#     request.load_chunks()  # loads all chunks in the request
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\napari\components\experimental\chunk\_request.py", line 243, in load_chunks
#     loaded_array = np.asarray(array)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\xarray\core\common.py", line 143, in __array__
#     return np.asarray(self.values, dtype=dtype)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\xarray\core\dataarray.py", line 642, in values
#     return self.variable.values
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\xarray\core\variable.py", line 512, in values
#     return _as_array_or_item(self._data)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\xarray\core\variable.py", line 252, in _as_array_or_item
#     data = np.asarray(data)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\aicsimageio\utils\dask_proxy.py", line 69, in __array__
#     return self.__wrapped__.__array__(dtype, **kwargs)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\array\core.py", line 1638, in __array__
#     x = self.compute()
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\base.py", line 292, in compute
#     (result,) = compute(self, traverse=False, **kwargs)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\base.py", line 575, in compute
#     results = schedule(dsk, keys, **kwargs)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\threaded.py", line 81, in get
#     results = get_async(
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\local.py", line 508, in get_async
#     raise_exception(exc, tb)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\local.py", line 316, in reraise
#     raise exc
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\local.py", line 221, in execute_task
#     result = _execute_task(task, data)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\core.py", line 119, in _execute_task
#     return func(*(_execute_task(a, cache) for a in args))
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\core.py", line 119, in <genexpr>
#     return func(*(_execute_task(a, cache) for a in args))
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\core.py", line 119, in _execute_task
#     return func(*(_execute_task(a, cache) for a in args))
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\optimization.py", line 990, in __call__
#     return core.get(self.dsk, self.outkey, dict(zip(self.inkeys, args)))
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\core.py", line 149, in get
#     result = _execute_task(task, cache)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\core.py", line 119, in _execute_task
#     return func(*(_execute_task(a, cache) for a in args))
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\core.py", line 119, in <genexpr>
#     return func(*(_execute_task(a, cache) for a in args))
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\core.py", line 113, in _execute_task
#     return [_execute_task(a, cache) for a in arg]
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\core.py", line 113, in <listcomp>
#     return [_execute_task(a, cache) for a in arg]
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\core.py", line 119, in _execute_task
#     return func(*(_execute_task(a, cache) for a in args))
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\array\core.py", line 515, in _pass_extra_kwargs
#     return func(*args[len(keys) :], **kwargs)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\aicsimageio\readers\bioformats_reader.py", line 525, in _dask_chunk
#     im = self._get_plane(t, c, z)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\aicsimageio\readers\bioformats_reader.py", line 485, in _get_plane
#     idx = self._r.getIndex(z, c, t)
# java.lang.java.lang.IllegalArgumentException: java.lang.IllegalArgumentException: Dimension order is null
# exception calling callback for <Future at 0x228e5cb04f0 state=finished raised java.lang.IllegalArgumentException>
# Traceback (most recent call last):
#   File "ImageReader.java", line 539, in loci.formats.ImageReader.getIndex
#   File "FormatReader.java", line 1105, in loci.formats.FormatReader.getIndex
#   File "FormatTools.java", line 408, in loci.formats.FormatTools.getIndex
#   File "FormatTools.java", line 456, in loci.formats.FormatTools.getIndex
# Exception: Java Exception
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\Linux\.conda\envs\bio11\lib\concurrent\futures\_base.py", line 330, in _invoke_callbacks
#     callback(self)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\napari\components\experimental\chunk\_pool.py", line 153, in _on_done
#     request = self._get_request(future)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\napari\components\experimental\chunk\_pool.py", line 189, in _get_request
#     return future.result()
#   File "C:\Users\Linux\.conda\envs\bio11\lib\concurrent\futures\_base.py", line 439, in result
#     return self.__get_result()
#   File "C:\Users\Linux\.conda\envs\bio11\lib\concurrent\futures\_base.py", line 391, in __get_result
#     raise self._exception
#   File "C:\Users\Linux\.conda\envs\bio11\lib\concurrent\futures\thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\napari\components\experimental\chunk\_pool.py", line 223, in _chunk_loader_worker
#     request.load_chunks()  # loads all chunks in the request
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\napari\components\experimental\chunk\_request.py", line 243, in load_chunks
#     loaded_array = np.asarray(array)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\xarray\core\common.py", line 143, in __array__
#     return np.asarray(self.values, dtype=dtype)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\xarray\core\dataarray.py", line 642, in values
#     return self.variable.values
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\xarray\core\variable.py", line 512, in values
#     return _as_array_or_item(self._data)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\xarray\core\variable.py", line 252, in _as_array_or_item
#     data = np.asarray(data)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\aicsimageio\utils\dask_proxy.py", line 69, in __array__
#     return self.__wrapped__.__array__(dtype, **kwargs)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\array\core.py", line 1638, in __array__
#     x = self.compute()
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\base.py", line 292, in compute
#     (result,) = compute(self, traverse=False, **kwargs)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\base.py", line 575, in compute
#     results = schedule(dsk, keys, **kwargs)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\threaded.py", line 81, in get
#     results = get_async(
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\local.py", line 508, in get_async
#     raise_exception(exc, tb)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\local.py", line 316, in reraise
#     raise exc
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\local.py", line 221, in execute_task
#     result = _execute_task(task, data)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\core.py", line 119, in _execute_task
#     return func(*(_execute_task(a, cache) for a in args))
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\core.py", line 119, in <genexpr>
#     return func(*(_execute_task(a, cache) for a in args))
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\core.py", line 119, in _execute_task
#     return func(*(_execute_task(a, cache) for a in args))
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\optimization.py", line 990, in __call__
#     return core.get(self.dsk, self.outkey, dict(zip(self.inkeys, args)))
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\core.py", line 149, in get
#     result = _execute_task(task, cache)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\core.py", line 119, in _execute_task
#     return func(*(_execute_task(a, cache) for a in args))
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\core.py", line 119, in <genexpr>
#     return func(*(_execute_task(a, cache) for a in args))
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\core.py", line 113, in _execute_task
#     return [_execute_task(a, cache) for a in arg]
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\core.py", line 113, in <listcomp>
#     return [_execute_task(a, cache) for a in arg]
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\core.py", line 119, in _execute_task
#     return func(*(_execute_task(a, cache) for a in args))
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\array\core.py", line 515, in _pass_extra_kwargs
#     return func(*args[len(keys) :], **kwargs)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\aicsimageio\readers\bioformats_reader.py", line 525, in _dask_chunk
#     im = self._get_plane(t, c, z)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\aicsimageio\readers\bioformats_reader.py", line 485, in _get_plane
#     idx = self._r.getIndex(z, c, t)
# java.lang.java.lang.IllegalArgumentException: java.lang.IllegalArgumentException: Dimension order is null
# exception calling callback for <Future at 0x228e81dbb20 state=finished raised java.lang.IllegalArgumentException>
# Traceback (most recent call last):
#   File "ImageReader.java", line 539, in loci.formats.ImageReader.getIndex
#   File "FormatReader.java", line 1105, in loci.formats.FormatReader.getIndex
#   File "FormatTools.java", line 408, in loci.formats.FormatTools.getIndex
#   File "FormatTools.java", line 456, in loci.formats.FormatTools.getIndex
# Exception: Java Exception
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\Linux\.conda\envs\bio11\lib\concurrent\futures\_base.py", line 330, in _invoke_callbacks
#     callback(self)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\napari\components\experimental\chunk\_pool.py", line 153, in _on_done
#     request = self._get_request(future)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\napari\components\experimental\chunk\_pool.py", line 189, in _get_request
#     return future.result()
#   File "C:\Users\Linux\.conda\envs\bio11\lib\concurrent\futures\_base.py", line 439, in result
#     return self.__get_result()
#   File "C:\Users\Linux\.conda\envs\bio11\lib\concurrent\futures\_base.py", line 391, in __get_result
#     raise self._exception
#   File "C:\Users\Linux\.conda\envs\bio11\lib\concurrent\futures\thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\napari\components\experimental\chunk\_pool.py", line 223, in _chunk_loader_worker
#     request.load_chunks()  # loads all chunks in the request
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\napari\components\experimental\chunk\_request.py", line 243, in load_chunks
#     loaded_array = np.asarray(array)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\xarray\core\common.py", line 143, in __array__
#     return np.asarray(self.values, dtype=dtype)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\xarray\core\dataarray.py", line 642, in values
#     return self.variable.values
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\xarray\core\variable.py", line 512, in values
#     return _as_array_or_item(self._data)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\xarray\core\variable.py", line 252, in _as_array_or_item
#     data = np.asarray(data)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\aicsimageio\utils\dask_proxy.py", line 69, in __array__
#     return self.__wrapped__.__array__(dtype, **kwargs)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\array\core.py", line 1638, in __array__
#     x = self.compute()
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\base.py", line 292, in compute
#     (result,) = compute(self, traverse=False, **kwargs)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\base.py", line 575, in compute
#     results = schedule(dsk, keys, **kwargs)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\threaded.py", line 81, in get
#     results = get_async(
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\local.py", line 508, in get_async
#     raise_exception(exc, tb)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\local.py", line 316, in reraise
#     raise exc
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\local.py", line 221, in execute_task
#     result = _execute_task(task, data)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\core.py", line 119, in _execute_task
#     return func(*(_execute_task(a, cache) for a in args))
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\core.py", line 119, in <genexpr>
#     return func(*(_execute_task(a, cache) for a in args))
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\core.py", line 119, in _execute_task
#     return func(*(_execute_task(a, cache) for a in args))
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\optimization.py", line 990, in __call__
#     return core.get(self.dsk, self.outkey, dict(zip(self.inkeys, args)))
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\core.py", line 149, in get
#     result = _execute_task(task, cache)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\core.py", line 119, in _execute_task
#     return func(*(_execute_task(a, cache) for a in args))
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\core.py", line 119, in <genexpr>
#     return func(*(_execute_task(a, cache) for a in args))
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\core.py", line 113, in _execute_task
#     return [_execute_task(a, cache) for a in arg]
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\core.py", line 113, in <listcomp>
#     return [_execute_task(a, cache) for a in arg]
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\core.py", line 119, in _execute_task
#     return func(*(_execute_task(a, cache) for a in args))
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\dask\array\core.py", line 515, in _pass_extra_kwargs
#     return func(*args[len(keys) :], **kwargs)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\aicsimageio\readers\bioformats_reader.py", line 525, in _dask_chunk
#     im = self._get_plane(t, c, z)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\aicsimageio\readers\bioformats_reader.py", line 485, in _get_plane
#     idx = self._r.getIndex(z, c, t)
# java.lang.java.lang.IllegalArgumentException: java.lang.IllegalArgumentException: Dimension order is null
# exception calling callback for <Future at 0x228e821d400 state=finished raised java.nio.channels.ClosedChannelException>
# Traceback (most recent call last):
#   File "ImageReader.java", line 849, in loci.formats.ImageReader.setId
#   File "TiffDelegateReader.java", line 92, in loci.formats.in.TiffDelegateReader.setId
#   File "FormatReader.java", line 1421, in loci.formats.FormatReader.setId
#   File "BaseTiffReader.java", line 591, in loci.formats.in.BaseTiffReader.initFile
#   File "MinimalTiffReader.java", line 483, in loci.formats.in.MinimalTiffReader.initFile
#   File "TiffParser.java", line 526, in loci.formats.tiff.TiffParser.fillInIFD
#   File "TiffParser.java", line 607, in loci.formats.tiff.TiffParser.getIFDValue
#   File "RandomAccessInputStream.java", line 574, in loci.common.RandomAccessInputStream.readUnsignedInt
#   File "RandomAccessInputStream.java", line 564, in loci.common.RandomAccessInputStream.readInt
#   File "NIOFileHandle.java", line 410, in loci.common.NIOFileHandle.readInt
#   File "NIOFileHandle.java", line 647, in loci.common.NIOFileHandle.buffer
#   File "NIOByteBufferProvider.java", line 112, in loci.common.NIOByteBufferProvider.allocate
#   File "NIOByteBufferProvider.java", line 127, in loci.common.NIOByteBufferProvider.allocateDirect
#   File "FileChannelImpl.java", line 790, in sun.nio.ch.FileChannelImpl.read
#   File "FileChannelImpl.java", line 150, in sun.nio.ch.FileChannelImpl.ensureOpen
# Exception: Java Exception
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\Linux\.conda\envs\bio11\lib\concurrent\futures\_base.py", line 330, in _invoke_callbacks
#     callback(self)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\napari\components\experimental\chunk\_pool.py", line 153, in _on_done
#     request = self._get_request(future)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\napari\components\experimental\chunk\_pool.py", line 189, in _get_request
#     return future.result()
#   File "C:\Users\Linux\.conda\envs\bio11\lib\concurrent\futures\_base.py", line 439, in result
#     return self.__get_result()
#   File "C:\Users\Linux\.conda\envs\bio11\lib\concurrent\futures\_base.py", line 391, in __get_result
#     raise self._exception
#   File "C:\Users\Linux\.conda\envs\bio11\lib\concurrent\futures\thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\napari\components\experimental\chunk\_pool.py", line 223, in _chunk_loader_worker
#     request.load_chunks()  # loads all chunks in the request
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\napari\components\experimental\chunk\_request.py", line 243, in load_chunks
#     loaded_array = np.asarray(array)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\xarray\core\common.py", line 143, in __array__
#     return np.asarray(self.values, dtype=dtype)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\xarray\core\dataarray.py", line 642, in values
#     return self.variable.values
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\xarray\core\variable.py", line 512, in values
#     return _as_array_or_item(self._data)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\xarray\core\variable.py", line 252, in _as_array_or_item
#     data = np.asarray(data)
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\aicsimageio\utils\dask_proxy.py", line 68, in __array__
#     with self._file_ctx if self._file_ctx.closed else nullcontext():  # type: ignore
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\aicsimageio\readers\bioformats_reader.py", line 440, in __enter__
#     self.open()
#   File "C:\Users\Linux\.conda\envs\bio11\lib\site-packages\aicsimageio\readers\bioformats_reader.py", line 356, in open
#     self._r.setId(self._path)
# java.nio.channels.java.nio.channels.ClosedChannelException: java.nio.channels.ClosedChannelException

# %%
images = (r"D:\EHG\Gonad\Raw\19-48-26_EH3574_PCW106_5-COUPTFII_6-Oct4_7-Sox9_12x_1z_STITCHED.ome_C1.zarr",r"D:\EHG\Gonad\Raw\19-48-26_EH3574_PCW106_5-COUPTFII_6-Oct4_7-Sox9_12x_1z_STITCHED.ome_C0.zarr")

Oct4 = (zr.load(images[0]))
lazy_Oct4 = (lazy_load(images[0]))
lazy_Sox9 = (lazy_load(images[1]))

dask_Oct4 = da.from_delayed(lazy_Oct4, shape=Oct4.shape, dtype=Oct4.dtype)
dask_Sox9 = da.from_delayed(lazy_Sox9, shape=Oct4.shape, dtype=Oct4.dtype)

dask_Oct4.shape
dask_Sox9.shape

print(Oct4.shape)
dask_Oct4

# %%
dask_Sox9

# %%
desired_chunksize = np.array([10,2,2])

# %%
rechunked_Oct4 = dask_Oct4.rechunk(desired_chunksize)
rechunked_Oct4

# %%
import napari
from napari.utils import nbscreenshot
import nest_asyncio
nest_asyncio.apply()

# %%
v = napari.Viewer()
v.add_image(dask_Oct4, name="Oct4", contrast_limits=[0,1], cache=False)
v.add_image(dask_Sox9, name="Sox9", contrast_limits=[0,1], cache=False)

# %%
labels = (r"G:\Stardist_results\LblImg_19-48-26_EH3574_PCW106_5-COUPTFII_6-Oct4_7-Sox9_12x_1z_STITCHED.ome_C1.tif1.zarr", r"G:\Stardist_results\LblImg_19-48-26_EH3574_PCW106_5-COUPTFII_6-Oct4_7-Sox9_12x_1z_STITCHED_C0_lbl.tif1.zarr")

Oct4l = (zr.load(labels[0]))
lazy_labels = [lazy_load(lbl) for lbl in labels]
dask_labels = [
    da.from_delayed(delayed_reader, shape=Oct4l.shape, dtype=Oct4l.dtype)
    for delayed_reader in lazy_labels
]

lstack = da.stack(dask_labels, axis=0)
lstack.shape

lstack

# %%
import napari
from napari.utils import nbscreenshot

# %%
v = napari.Viewer()
v.add_image(istack, contrast_limits=[0,2000], multiscale=False)
